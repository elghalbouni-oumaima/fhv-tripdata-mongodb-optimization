# %%
from dotenv import load_dotenv
import os
import sys

load_dotenv()  # Load variables from .env

project_root = os.getenv("project_root")
sys.path.append(project_root)

# %%
#check if we are running inside the correct virtual environment.
import sys
print(sys.executable)

# %% [markdown]
# ## Extract Data

# %%
import pandas as pd
import pyarrow.parquet as pq

# %%
trips = pq.read_table('../data/raw/fhvhv_tripdata_2021-10.parquet')
trips = trips.to_pandas()

# %% [markdown]
# ## Explore Data

# %%
trips.describe()

# %%
trips.dtypes

# %%
trips.info()

# %%
trips.value_counts()

# %% [markdown]
# >hvfhs_license_num	Company (Uber/Lyft)
#
# >dispatching_base_num	Base that dispatched the trip
#
# >originating_base_num	Original base that got the request
#
# >request_datetime	When the trip was requested
#
# >on_scene_datetime	Driver arrives
#
# >pickup_datetime	Trip starts
#
# >dropoff_datetime	Trip ends
#
# >PULocationID	Pickup zone
#
# >DOLocationID	Dropoff zone
#
# >trip_miles	Distance
#
# >trip_time	Duration
#
# >base_passenger_fare	Base fare
#
# >tolls	Toll fees
#
# >bcf	Black Car Fund surcharge
#
# >sales_tax	Tax
#
# >congestion_surcharge	NYC congestion fee
#
# >airport_fee	Airport access fee
#
# >tips	Tips
#
# >driver_pay	Driver earnings
#
# >shared_request_flag	Passenger asked for shared ride
#
# >shared_match_flag	Shared ride matched
#
# >access_a_ride_flag	Handicapped program
#
# >wav_request_flag	Wheelchair-accessible vehicle requested
#
# >wav_match_flag	WAV matched

# %%
trips.columns

# %%
trips['originating_base_num'].value_counts().count()

# %% [markdown]
# >isna() and isnull() are aliases
#
# Pandas created both names for convenience.
#
# ✔ Both detect missing values:
#
# NaN
#
# None
#
# NaT
#
# empty/null values

# %%
trips.isnull().sum()

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Drop Columns

# %%
trips.drop(columns=['originating_base_num'],inplace=True,axis=1)

# %%
trips.drop(columns=['on_scene_datetime'],inplace=True,axis=1)

# %%
trips.drop(columns=['access_a_ride_flag'],inplace=True)

# %%
trips.head()

# %%
trips['wav_request_flag'].value_counts()

# %%
trips['wav_match_flag'].value_counts()

# %%
trips['shared_request_flag'].value_counts()

# %%
trips['shared_match_flag'].value_counts()

# %% [markdown]
# ### Repalce boolean columns

# %%
trips.replace({
    'shared_request_flag':{'N':0,'Y':1},
    'wav_match_flag':{'N':0,'Y':1},
    'wav_request_flag':{'N':0,'Y':1},
    'shared_match_flag':{'N':0,'Y':1}
},
inplace=True)

# %%
trips.head()

# %% [markdown]
# ### Convert data type

# %%
trips.dtypes

# %%
trips.dtypes == 'datetime64[us]'

# %%
trips.dtypes == 'int64'

# %%
for x in trips:
    print(x)

# %%
for x in trips:
    if(trips[x].dtypes == 'datetime64[us]'):
        trips[x] = pd.to_datetime(trips[x])

# %%
for x in trips:
    if(trips[x].dtypes == 'int64'):
        trips[x] = trips[x].astype(int)

# %%
for x in trips:
    if(trips[x].dtypes == 'float64'):
        trips[x] = trips[x].astype(float)

# %% [markdown]
# ## Add Index

# %%
trips['row_id'] = trips.index

# %% [markdown]
# # Test src.benchmarks.benchmarks_app.py

# %%
from src.mongo_import import connect_to_mongo

DB_NAME = "trips_db"
COLLECTION_NAME = "fhvhv_trips_2021-10"
db = connect_to_mongo(DB_NAME)
collection = db[COLLECTION_NAME]
pipeline = [
{ "$group": { "_id": "$hvfhs_license_num", "total": { "$sum": 1 }, "avg_trip_time": { "$avg": "$trip_time" } } },
{ "$match": { "avg_trip_time": { "$gte": 300 } } }
]

# %%
m = db.command("explain", {
    "aggregate": collection.name,
    "pipeline": pipeline,
    
    })

# %%
m.get("stages", {})

# %%
from src.benchmarks.benchmarks_app import run_benchmark

# %%
q = {'trip_time':{'$gte': 300}}
run_benchmark(
    query=q,
    index_param={ "trip_time": 1 },
    index_name="simple_index"
)
# Out:
# {'trip_time': {'$gte': 300}}
# <pymongo.synchronous.cursor.Cursor object at 0x00000289019E51D0>
# ---------------------------------------------------------------------------
# _OperationCancelled                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 q = {'trip_time':{'$gte': 300}}
# ----> 2 run_benchmark(
#       3     query=q,
#       4     index_param={ "trip_time": 1 },
#       5     index_name="simple_index"
#       6 )
#
# File ~\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\src\benchmarks\benchmarks_app.py:149, in run_benchmark(query, index_param, index_name, typeOfQuery)
#     146 def run_benchmark(query, index_param, index_name,typeOfQuery='find'):
#     147     #Before Index
#     148     print(query)
# --> 149     metrics_before = run_explain(query,typeOfQuery=typeOfQuery)
#     150     filename = save_metrics( metrics_before, index_param, index_name, filename=None)
#     152     #After Index
#
# File ~\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\src\benchmarks\benchmarks_app.py:29, in run_explain(query, coll, sort, typeOfQuery)
#      27     #lauch explain with execution statistics
#      28     print(cursor)
# ---> 29     explain_data = cursor.explain()
#      30 else:
#      31     raise ValueError(f"Unsupported query type: {typeOfQuery}")
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\synchronous\cursor.py:778, in Cursor.explain(self)
#     776 if c._limit:
#     777     c._limit = -abs(c._limit)
# --> 778 return next(c)
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\synchronous\cursor.py:1289, in Cursor.__next__(self)
#    1288 def __next__(self) -> _DocumentType:
# -> 1289     return self.next()
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\synchronous\cursor.py:1265, in Cursor.next(self)
#    1263 if self._empty:
#    1264     raise StopIteration
# -> 1265 if len(self._data) or self._refresh():
#    1266     return self._data.popleft()
#    1267 else:
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\synchronous\cursor.py:1213, in Cursor._refresh(self)
#    1191         raise InvalidOperation(
#    1192             "Passing a 'hint' is required when using the min/max query"
#    1193             " option to ensure the query utilizes the correct index"
#    1194         )
#    1195     q = self._query_class(
#    1196         self._query_flags,
#    1197         self._collection.database.name,
#    (...)   1211         self._exhaust,
#    1212     )
# -> 1213     self._send_message(q)
#    1214 elif self._id:  # Get More
#    1215     if self._limit:
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\synchronous\cursor.py:1108, in Cursor._send_message(self, operation)
#    1105     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1107 try:
# -> 1108     response = client._run_operation(
#    1109         operation, self._unpack_response, address=self._address
#    1110     )
#    1111 except OperationFailure as exc:
#    1112     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1113         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1938, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1928     operation.reset()  # Reset op in case of retry.
#    1929     return server.run_operation(
#    1930         conn,
#    1931         operation,
#    (...)   1935         self,
#    1936     )
# -> 1938 return self._retryable_read(
#    1939     _cmd,
#    1940     operation.read_preference,
#    1941     operation.session,  # type: ignore[arg-type]
#    1942     address=address,
#    1943     retryable=isinstance(operation, _Query),
#    1944     operation=operation.name,
#    1945 )
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2047, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2042 # Ensure that the client supports retrying on reads and there is no session in
#    2043 # transaction, otherwise, we will not support retry behavior for this call.
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
# -> 2047 return self._retry_internal(
#    2048     func,
#    2049     session,
#    2050     None,
#    2051     operation,
#    2052     is_read=True,
#    2053     address=address,
#    2054     read_pref=read_pref,
#    2055     retryable=retryable,
#    2056     operation_id=operation_id,
#    2057 )
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)   1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)   2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2926, in _ClientConnectionRetryable._read(self)
#    2918 if self._retrying:
#    2919     _debug_log(
#    2920         _COMMAND_LOGGER,
#    2921         message=f"Retrying read attempt number {self._attempt_number}",
#    (...)   2924         operationId=self._operation_id,
#    2925     )
# -> 2926 return self._func(self._session, self._server, conn, read_pref)
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1929, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1922 def _cmd(
#    1923     _session: Optional[ClientSession],
#    1924     server: Server,
#    1925     conn: Connection,
#    1926     read_preference: _ServerMode,
#    1927 ) -> Response:
#    1928     operation.reset()  # Reset op in case of retry.
# -> 1929     return server.run_operation(
#    1930         conn,
#    1931         operation,
#    1932         read_preference,
#    1933         self._event_listeners,
#    1934         unpack_res,
#    1935         self,
#    1936     )
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\synchronous\server.py:208, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res, client)
#     206 else:
#     207     conn.send_message(data, max_doc_size)
# --> 208     reply = conn.receive_message(request_id)
#     210 # Unpack and check for command errors.
#     211 if use_cmd:
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\synchronous\pool.py:469, in Connection.receive_message(self, request_id)
#     467 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     468 except BaseException as error:
# --> 469     self._raise_connection_failure(error)
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\synchronous\pool.py:466, in Connection.receive_message(self, request_id)
#     461 """Receive a raw BSON message or raise ConnectionFailure.
#     462
#     463 If any exception is raised, the socket is closed.
#     464 """
#     465 try:
# --> 466     return receive_message(self, request_id, self.max_message_size)
#     467 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     468 except BaseException as error:
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\network_layer.py:759, in receive_message(conn, request_id, max_message_size)
#     757         deadline = None
#     758 # Ignore the response's request id.
# --> 759 length, _, response_to, op_code = _UNPACK_HEADER(receive_data(conn, 16, deadline))
#     760 # No request_id for exhaust cursor "getMore".
#     761 if request_id is not None:
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\network_layer.py:343, in receive_data(conn, length, deadline)
#     339 try:
#     340     # Use the legacy wait_for_read cancellation approach on PyPy due to PYTHON-5011.
#     341     # also use it on Windows due to PYTHON-5405
#     342     if _PYPY or _WINDOWS:
# --> 343         wait_for_read(conn, deadline)
#     344         if _csot.get_timeout() and deadline is not None:
#     345             conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
#
# File c:\Users\dell\Downloads\projet BDD\fhv-tripdata-mongodb-optimization\venv\Lib\site-packages\pymongo\network_layer.py:318, in wait_for_read(conn, deadline)
#     316     readable = conn.socket_checker.select(sock, read=True, timeout=timeout)
#     317 if conn.cancel_context.cancelled:
# --> 318     raise _OperationCancelled("operation cancelled")
#     319 if readable:
#     320     return
#
# _OperationCancelled: operation cancelled
